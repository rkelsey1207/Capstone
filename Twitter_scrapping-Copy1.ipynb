# %%
pip install pyquery
# Out:
# Collecting pyquery
#   Using cached https://files.pythonhosted.org/packages/09/c7/ce8c9c37ab8ff8337faad3335c088d60bed4a35a4bed33a64f0e64fbcf29/pyquery-1.4.0-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=2.1 in /Users/bobbykelsey/anaconda3/envs/dsi2/lib/python3.7/site-packages (from pyquery) (4.3.4)
# Collecting cssselect>0.7.9 (from pyquery)
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Installing collected packages: cssselect, pyquery
# Successfully installed cssselect-1.1.0 pyquery-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import tweepy
import datetime
import time
from pandas.io.json import json_normalize
import GetOldTweets3 as got
pd.options.display.max_rows= 999999

# %%
import GetOldTweets3 as got

# %%
auth = tweepy.OAuthHandler('zf40UHP75EK6FmKz8CovROxbv', 'hKsT5dFDjUcsTjDrXdwyrhn06fhpljR20FVc9LDLwLAxj2buSU')
auth.set_access_token('1153661200128970752-aKRuJUjfuevWtrrGt5rGPHGQbq8dPm', '7h7BzmHBSAugT75DoiqtfGJNXnS5oKnTziIgKgiuh04si' )

# %%
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
my_accounts = []
for friend in tweepy.Cursor(api.friends).items():
    my_accounts.append(friend.screen_name)

my_accounts
# Out:
# ['TDLockett12',
#  'Ebron85',
#  'VernonDavis85',
#  'JaredCook89',
#  'AustinEkeler',
#  'RyanGrant25',
#  'Marlon_Mack25',
#  'CoreyClement_6',
#  'MattForte22',
#  'martavis1212',
#  'MattBreida',
#  'JordyRNelson',
#  'Will_Fuller7',
#  'JDoc_son',
#  'sterl_shep3',
#  'samajp32',
#  'JimmyG_10',
#  'kelvinbenjamin',
#  'DeSeanJackson11',
#  'cjbeathard',
#  'Air4Cole',
#  'TeamLee1',
#  'rcobb18',
#  'TyrellWilliams_',
#  'TravisBenjamin3',
#  'TarikCohen',
#  'Wallace17_daKid',
#  'Ameerguapo',
#  'RBrex34',
#  'LG_Blount',
#  'prichiejr',
#  'robertwoods',
#  'sammywatkins',
#  'Mo_12_Sanu',
#  'TedGinnJr_19',
#  'Jonathanstewar1',
#  'G_Bernard25',
#  'KDx32',
#  'AmariCooper9',
#  'JayTrain',
#  'ChrisThompson_4',
#  'IsaiahCrowell34',
#  'jswaggdaddy',
#  'OrleansDarkwa',
#  'realbuckallen',
#  'bilalpowell29',
#  'bretthundley7',
#  'KingHenry_2',
#  'TrevorSiemian',
#  'JetMckinnon1',
#  'AaronRodgers12',
#  'Mtrubisky10',
#  'deshaunwatson',
#  'deshonekizer',
#  'JoeFlacco',
#  'Jaboowins',
#  'JoshMcCown12',
#  'derekcarrqb',
#  'JBrissett12',
#  'andydalton14',
#  'TyrodTaylor',
#  'M_Ryan02',
#  'casekeenum',
#  'Alex_Armah',
#  'Hunter_Henry84',
#  'JaredGoff16',
#  'JKearse_15',
#  'Kroft86',
#  'marquisegoodwin',
#  'JasonWitten',
#  'KingCrab15',
#  'CooperKupp',
#  'DeMarcoMurray',
#  'dak',
#  '_BigBen7',
#  'KSTiLLS',
#  'DezBryant',
#  'drewbrees',
#  'TYHilton13',
#  'DemaryiusT',
#  'Teco_Raww',
#  'nelsonagholor',
#  'DukeJohnson_8',
#  'LataviusM',
#  'frankgore',
#  'delaniewalker82',
#  'KyleRudolph82',
#  'cjandersonb22',
#  'Budda03',
#  'D_FUNCH',
#  'MikeEvans13_',
#  'ShowtimeTate',
#  'run__cmc',
#  'KirkCousins8',
#  'stefondiggs',
#  'youngamazing9',
#  'cj_wentz',
#  'eazyengram',
#  'TheWorldof_AJ',
#  'TeamJuJu',
#  'millertime_6',
#  'God_Son80',
#  'devontafreeman',
#  'DougBaldwinJr',
#  'tae15adams',
#  'athielen19',
#  'TomBrady',
#  'ajgreen_18',
#  'LarryFitzgerald',
#  'Cantguardmike',
#  'DionLewisRB',
#  'CameronNewton',
#  'brandincooks',
#  'ZERTZ_86',
#  'elguapo',
#  'JHowardx24',
#  'EzekielElliott',
#  'MarvinJonesJr',
#  'cheetah',
#  'Keenan13Allen',
#  '_fournette',
#  'tkelce',
#  'RobGronkowski',
#  'CutonDime25',
#  'DangeRussWilson',
#  'markingram21',
#  'AB84',
#  'DeAndreHopkins',
#  'Melvingordon25',
#  'A_kamara6',
#  'Kareemhunt7',
#  'LeVeonBell',
#  'TG3II']

# %%
my_accounts
# Out:
# ['TDLockett12',
#  'Ebron85',
#  'VernonDavis85',
#  'JaredCook89',
#  'AustinEkeler',
#  'RyanGrant25',
#  'Marlon_Mack25',
#  'CoreyClement_6',
#  'MattForte22',
#  'martavis1212',
#  'MattBreida',
#  'JordyRNelson',
#  'Will_Fuller7',
#  'JDoc_son',
#  'sterl_shep3',
#  'samajp32',
#  'JimmyG_10',
#  'kelvinbenjamin',
#  'DeSeanJackson11',
#  'cjbeathard',
#  'Air4Cole',
#  'TeamLee1',
#  'rcobb18',
#  'TyrellWilliams_',
#  'TravisBenjamin3',
#  'TarikCohen',
#  'Wallace17_daKid',
#  'Ameerguapo',
#  'RBrex34',
#  'LG_Blount',
#  'prichiejr',
#  'robertwoods',
#  'sammywatkins',
#  'Mo_12_Sanu',
#  'TedGinnJr_19',
#  'Jonathanstewar1',
#  'G_Bernard25',
#  'KDx32',
#  'AmariCooper9',
#  'JayTrain',
#  'ChrisThompson_4',
#  'IsaiahCrowell34',
#  'jswaggdaddy',
#  'OrleansDarkwa',
#  'realbuckallen',
#  'bilalpowell29',
#  'bretthundley7',
#  'KingHenry_2',
#  'TrevorSiemian',
#  'JetMckinnon1',
#  'AaronRodgers12',
#  'Mtrubisky10',
#  'deshaunwatson',
#  'deshonekizer',
#  'JoeFlacco',
#  'Jaboowins',
#  'JoshMcCown12',
#  'derekcarrqb',
#  'JBrissett12',
#  'andydalton14',
#  'TyrodTaylor',
#  'M_Ryan02',
#  'casekeenum',
#  'Alex_Armah',
#  'Hunter_Henry84',
#  'JaredGoff16',
#  'JKearse_15',
#  'Kroft86',
#  'marquisegoodwin',
#  'JasonWitten',
#  'KingCrab15',
#  'CooperKupp',
#  'DeMarcoMurray',
#  'dak',
#  '_BigBen7',
#  'KSTiLLS',
#  'DezBryant',
#  'drewbrees',
#  'TYHilton13',
#  'DemaryiusT',
#  'Teco_Raww',
#  'nelsonagholor',
#  'DukeJohnson_8',
#  'LataviusM',
#  'frankgore',
#  'delaniewalker82',
#  'KyleRudolph82',
#  'cjandersonb22',
#  'Budda03',
#  'D_FUNCH',
#  'MikeEvans13_',
#  'ShowtimeTate',
#  'run__cmc',
#  'KirkCousins8',
#  'stefondiggs',
#  'youngamazing9',
#  'cj_wentz',
#  'eazyengram',
#  'TheWorldof_AJ',
#  'TeamJuJu',
#  'millertime_6',
#  'God_Son80',
#  'devontafreeman',
#  'DougBaldwinJr',
#  'tae15adams',
#  'athielen19',
#  'TomBrady',
#  'ajgreen_18',
#  'LarryFitzgerald',
#  'Cantguardmike',
#  'DionLewisRB',
#  'CameronNewton',
#  'brandincooks',
#  'ZERTZ_86',
#  'elguapo',
#  'JHowardx24',
#  'EzekielElliott',
#  'MarvinJonesJr',
#  'cheetah',
#  'Keenan13Allen',
#  '_fournette',
#  'tkelce',
#  'RobGronkowski',
#  'CutonDime25',
#  'DangeRussWilson',
#  'markingram21',
#  'AB84',
#  'DeAndreHopkins',
#  'Melvingordon25',
#  'A_kamara6',
#  'Kareemhunt7',
#  'LeVeonBell',
#  'TG3II']

# %%
max_tweets=100000000
closure_list=[]
final_df=pd.DataFrame()
for account in my_accounts:
    tweetCriteria = got.manager.TweetCriteria().setUsername(account).setSince("2017-08-23").setUntil("2017-12-31").setMaxTweets(max_tweets)   
    print(tweetCriteria)
    tweet = got.manager.TweetManager.getTweets(tweetCriteria)
    for i in range(len(tweet)):
        tweet_dict = {}
        tweet_dict['id'] = tweet[i].id
        tweet_dict['username'] = tweet[i].username
        tweet_dict['date'] = tweet[i].date
        tweet_dict['text'] = tweet[i].text
        tweet_dict['hashtags'] = tweet[i].hashtags
        tweet_dict['geo'] = tweet[i].geo
        tweet_dict['type'] = 'official'
        closure_list.append(tweet_dict)


df1=pd.DataFrame(closure_list)
final_df = pd.concat([df1, final_df])
print("Shape of DataFrame:", final_df.shape)
# Out:
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11e202a20>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f49e5c0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef44630>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x10ce254e0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11e211f60>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11c6b0ef0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11e211f60>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef44080>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ecda780>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f415198>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11e211f60>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1cde10>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f4747f0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d14ac50>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f474898>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11c6b7630>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef27ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef44630>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f543be0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5430b8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1cd198>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ecda780>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d14ab00>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f4747f0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1cd3c8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x10ce009b0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1cd3c8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1bf2b0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11eede710>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef27ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x10ce00b70>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1bf2b0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d14abe0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef27ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f4ca780>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1bf2b0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f49ed68>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef27ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f598eb8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a8710>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b3828>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f474898>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a4978>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f598978>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d14ab00>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b44a8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f4991d0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef27ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a4358>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x10ce009b0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561048>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f499cf8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5983c8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f613828>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d14ab00>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f49e908>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f4991d0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a8518>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b44e0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef27ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b46d8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a4748>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d14ab00>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561780>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561978>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4588>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5985c0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561e80>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a4748>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f613908>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5985c0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f49e5f8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561a58>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11ef27ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f6132b0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4f98>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a85f8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a8780>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561a58>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a62b0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f49ea90>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc310f0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f601668>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a85f8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a6f60>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561048>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f6011d0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f543b70>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f543e48>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4198>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4860>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a6a20>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1398d0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a8780>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d139a58>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a6ac8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a85f8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc31dd8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d139a58>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a64e0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561048>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a85f8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4198>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a6748>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f543550>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d1392e8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f543320>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc31e48>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f543320>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f6237f0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4f28>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4dd8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc59e48>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc59f60>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f561048>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5b4198>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f543550>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a85f8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fffa978>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc59358>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a6748>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x1200fc0f0>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x120135b38>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc59f98>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11d139b00>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc317b8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a85f8>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc31f60>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc59860>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f5a6748>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11f49ea90>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fc59320>
# <GetOldTweets3.manager.TweetCriteria.TweetCriteria object at 0x11fae8cc0>
# Shape of DataFrame: (12253, 7)

# %%
final_df.to_csv('./datasets/player_tweets.csv')
